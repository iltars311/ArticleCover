# %%
import pandas as pd
import seaborn as sns
import json
from tqdm import tqdm
import matplotlib.pyplot as plt
import os

# %%
def load_jsonl(dataset_path, max_size):
    try:
        set_size = 0
        with open(dataset_path, "r", encoding='UTF-8') as file:
            for line in file:
                set_size += 1
        each_n = set_size // max_size if max_size < set_size else 1 
        max_size = min(set_size, max_size)
        with open(dataset_path, "r", encoding='UTF-8') as file:
            df_json = []
            for i, line in enumerate(tqdm(file, desc='Загрузка данных')):
                if len(df_json) >= max_size:
                    break
                if i % each_n == 0:
                    try:
                        df_json.append(json.loads(line))
                    except json.JSONDecodeError:
                        continue     
            return df_json
    except json.JSONDecodeError:
        raise RuntimeError('File format is not json or jsonl')
    except Exception as e:
        raise RuntimeError(f'An error occured during parsing: {e}')

# %%
def load_json(dataset_path, max_size):
    try:
        with open(dataset_path, "r", encoding='UTF-8') as file:
            df_json = json.load(file) 
            set_size = len(df_json)
            each_n = set_size // max_size if max_size < set_size else 1
            return df_json[::each_n]  
    except json.JSONDecodeError:
        return load_jsonl(dataset_path, max_size)
    except Exception as e:
        raise RuntimeError(f'An error occured during parsing: {e}')

# %%
def data_preprocessing_pipeline(dataset_path, max_size=100000, save=False, save_path='dataset.tsv', save_mode='w'): 
    if not os.path.exists(dataset_path):
        raise FileNotFoundError('dataset not found')
    
    df_json = load_json(dataset_path, max_size)
            
    df_origin = pd.DataFrame(columns = ['id', 'origin', 'title', 'abstract'])
    
    origin_idx = 0
    for art in tqdm(df_json, 'Создание pandas-DataFrame из данных'):
        if 'summary' in art or 'abstract' in art: 
            arxiv_id = art['id']
            title = art['title']
            abstract = art['summary'] if 'summary' in art else art['abstract']
            row = pd.DataFrame({
                'id' :  [arxiv_id],
                'origin' : [dataset_path.split('/')[-2]],
                'title' : [title],
                'abstract' : [abstract]
            })
            df_origin = pd.concat([df_origin, row], ignore_index=True)         
        origin_idx += 1

    df_clean = df_origin.copy()    

    print('Нормализация названий: ', end='')    
    df_clean['title'] = df_origin['title'].fillna('').str.replace(r'[\n\t]', ' ', regex=True)
    df_clean['title'] = df_clean['title'].str.replace(r'\s+', ' ', regex=True)
    print('выполнено.')

    print('Нормализация абстрактов: ', end='')  
    df_clean['abstract'] = df_origin['abstract'].fillna('').str.replace(r'[\n\t]', ' ', regex=True)
    df_clean['abstract'] = df_clean['abstract'].str.replace(r'\s+', ' ', regex=True)
    print('выполнено.')

    print('Сбор статистики размера абстрактов: ', end='')
    df_clean['words_num'] = df_clean['abstract'].str.count(' ') + 1
    df_clean['sents_num'] = df_clean['abstract'].str.count(r'[.!?]+ ') + 1 
    print('выполнено.')

    df_good = df_clean.copy()

    print('Формирование итоговой выборки: ', end='')
    df_good = df_good[df_good['words_num'] >= 50]
    df_good = df_good[df_good['words_num'] <= 250]
    df_good = df_good[df_good['sents_num'] <= 12]
    print('выполнено.')
    print(f"Выбрано: {df_good.shape[0]} статей из {df_clean.shape[0]} ({df_good.shape[0] / df_clean.shape[0] * 100:.3f}%)")

    df_fin = df_good.drop(columns=['words_num', 'sents_num'])

    if save:
        print('Сохранение датасета: ', end='')
        df_fin.to_csv(save_path, sep='\t', mode=save_mode, header=(save_mode == 'w'), index=False, encoding='utf-8-sig')
        print('выполнено.')

    fig, axes = plt.subplots(2, 2, figsize=(12, 12))
    ax_lu, ax_ru, ax_ld, ax_rd = axes.flatten()

    ax_lu.set_title('Распределение длины слов в абстракте в оригинале')
    sns.histplot(df_clean['words_num'], ax=ax_lu, kde=True)
    ax_ru.set_title('Распределение количества предложений в абстракте в оригинале')
    sns.histplot(df_clean['sents_num'], ax=ax_ru)
    ax_ld.set_title('Распределение длины слов в абстракте в итоге')
    sns.histplot(df_good['words_num'], ax=ax_ld, kde=True)
    ax_rd.set_title('Распределение количества предложений в абстракте в итоге')
    sns.histplot(df_good['sents_num'], ax=ax_rd)
    
    plt.tight_layout()
    plt.show()

    return df_fin.reset_index(drop=True)

# %%
data_preprocessing_pipeline('../origins/41Kmeta_en/arxivData.json', max_size=11, save=True, save_path='../dataset/clean.tsv', save_mode='w')
# Out:
# Создание pandas-DataFrame из данных: 100%|██████████| 12/12 [00:00<00:00, 644.26it/s]
# Нормализация названий: выполнено.
# Нормализация абстрактов: выполнено.
# Сбор статистики размера абстрактов: выполнено.
# Формирование итоговой выборки: выполнено.
# Выбрано: 12 статей из 12 (100.000%)
# Сохранение датасета: выполнено.
#               id      origin  \
# 0   1802.00209v1  41Kmeta_en
# 1   1803.02865v1  41Kmeta_en
# 2   1801.00507v1  41Kmeta_en
# 3    1411.6622v1  41Kmeta_en
# 4    1207.4625v1  41Kmeta_en
# 5    1106.4863v1  41Kmeta_en
# 6   1603.06340v1  41Kmeta_en
# 7   1608.06192v1  41Kmeta_en
# 8   1710.07307v1  41Kmeta_en
# 9   1612.05536v1  41Kmeta_en
# 10  1701.08878v1  41Kmeta_en
# 11   1404.5899v1  41Kmeta_en
#
#                                                 title  \
# 0   Dual Recurrent Attention Units for Visual Ques...
# 1   WNGrad: Learn the Learning Rate in Gradient De...
# 2     Towards Practical Conditional Risk Minimization
# ...

# %%
data_preprocessing_pipeline("../origins/3Mmeta_en/arxiv-metadata-oai-snapshot.json", max_size=100000, save=True, save_path='../dataset/clean.tsv', save_mode='a')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 data_preprocessing_pipeline("../origins/3Mmeta_en/arxiv-metadata-oai-snapshot.json", max_size=100000, save=True, save_path='../dataset/clean.tsv', save_mode='a')
#
# Cell In[15], line 5, in data_preprocessing_pipeline(dataset_path, max_size, save, save_path, save_mode)
#       2 if not os.path.exists(dataset_path):
#       3     raise FileNotFoundError('dataset not found')
# ----> 5 df_json = load_json(dataset_path, max_size)
#       7 df_origin = pd.DataFrame(columns = ['id', 'arxiv_id', 'title', 'abstract'])
#       9 origin_idx = 0
#
# Cell In[3], line 4, in load_json(dataset_path, max_size)
#       2 try:
#       3     with open(dataset_path, "r", encoding='UTF-8') as file:
# ----> 4         df_json = json.load(file)
#       5         set_size = len(df_json)
# ...

# %% [markdown]
# ***Далее &mdash; блоки-артефакты разработки пайплайна.***

# %%
with open("../origins/3Mmeta_en/arxiv-metadata-oai-snapshot.json", "r", encoding='UTF-8') as file:
    ds_json = []
    size = 0
    for line in tqdm(file, desc='Загрузка данных'):
        ds_json.append(json.loads(line))
        print(ds_json[size])
        size += 1
        if size >= 10:
            break
# Out:
# Загрузка данных: 9it [00:00, 685.68it/s]
# ...

# %%
with open("../origins/41Kmeta_en/arxivData.json", "r", encoding='UTF-8') as file:
    ds_json = json.load(file)
ds_json[0], len(ds_json)
# Out:
# ({'author': "[{'name': 'Ahmed Osman'}, {'name': 'Wojciech Samek'}]",
#   'day': 1,
#   'id': '1802.00209v1',
#   'link': "[{'rel': 'alternate', 'href': 'http://arxiv.org/abs/1802.00209v1', 'type': 'text/html'}, {'rel': 'related', 'href': 'http://arxiv.org/pdf/1802.00209v1', 'type': 'application/pdf', 'title': 'pdf'}]",
#   'month': 2,
# ...

# %%
df_origin = pd.DataFrame(columns = ['origin_idx', 'id', 'title', 'abstract'])
origin_idx = 0
for art in tqdm(ds_json):
    if 'summary' in art: 
        id = art['id']
        title = art['title']
        abstract = art['summary']
        row = pd.DataFrame({
            'origin_idx' : origin_idx,
            'id' : [id],
            'title' : [title],
            'abstract' : [abstract]
        })
        df_origin = pd.concat([df_origin, row], ignore_index=True)         
    origin_idx += 1
df_origin.head(5)
# Out:
# ...
# 100%|██████████| 41000/41000 [00:45<00:00, 895.17it/s]
#   origin_idx            id                                              title  \
# 0          0  1802.00209v1  Dual Recurrent Attention Units for Visual Ques...
# 1          1  1603.03827v1  Sequential Short-Text Classification with Recu...
# 2          2  1606.00776v2  Multiresolution Recurrent Neural Networks: An ...
# 3          3  1705.08142v2  Learning what to share between loosely related...
# 4          4  1709.02349v2              A Deep Reinforcement Learning Chatbot
#
#                                             abstract
# 0  We propose an architecture for VQA which utili...
# 1  Recent approaches based on artificial neural n...
# 2  We introduce the multiresolution recurrent neu...
# 3  Multi-task learning is motivated by the observ...
# 4  We present MILABOT: a deep reinforcement learn...

# %%
df_origin['abs_len'] = df_origin['abstract'].str.len()

# %%
df_good = df_origin[(df_origin['abs_len'] > 500) & (df_origin['abs_len'] < 2000)]
sns.histplot(df_good['abs_len'])
# Out:
# <Axes: xlabel='abs_len', ylabel='Count'>

# %%
df_good.min()
# Out:
# origin_idx                                                    0
# id                                                  0704.1020v1
# title         "Attention" for Detecting Unreliable News in t...
# abstract      "Background subtraction" is an old technique f...
# abs_len                                                     501
# dtype: object

# %%
df_good[df_good['abs_len'] == 501]
# Out:
#       origin_idx            id  \
# 6642        6642  1704.06656v1
# 8766        8766  cs/0103002v1
# 10428      10428   1308.4214v1
# 11985      11985  1705.09869v2
# 13362      13362   1103.2741v1
# 17297      17297  1710.01411v1
# 20154      20154   1411.7480v1
# 24912      24912   1412.7851v1
# 32048      32048   1406.3726v1
# 32058      32058   1406.6176v1
# 33020      33020  1712.08987v1
# 33650      33650  1504.02972v1
# 37516      37516  1709.00744v1
# 38369      38369  1703.06108v1
#
#                                                    title  \
# 6642   Feature selection algorithm based on Catastrop...
# 8766   Quantitative Neural Network Model of the Tip-o...
# 10428      Pylearn2: a machine learning research library
# 11985  Dimensionality reduction for acoustic vehicle ...
# 13362    Memory Retrieval in the B-Matrix Neural Network
# 17297  Transferring Semantic Roles Using Translation ...
# 20154  Unweighted Stochastic Local Search can be Effe...
# ...

# %%
df_good.loc[6642]['abstract']
# Out:
# 'In this paper we introduce a new feature selection algorithm to remove the\nirrelevant or redundant features in the data sets. In this algorithm the\nimportance of a feature is based on its fitting to the Catastrophe model.\nAkaike information crite- rion value is used for ranking the features in the\ndata set. The proposed algorithm is compared with well-known RELIEF feature\nselection algorithm. Breast Cancer, Parkinson Telemonitoring data and Slice\nlocality data sets are used to evaluate the model.'

# %%
df_origin.drop('good', axis=1, inplace=True)
df_origin.drop('abs_len', axis=1, inplace=True)

# %%
df_origin.head()
# Out:
#   origin_idx            id                                              title  \
# 0          0  1802.00209v1  Dual Recurrent Attention Units for Visual Ques...
# 1          1  1603.03827v1  Sequential Short-Text Classification with Recu...
# 2          2  1606.00776v2  Multiresolution Recurrent Neural Networks: An ...
# 3          3  1705.08142v2  Learning what to share between loosely related...
# 4          4  1709.02349v2              A Deep Reinforcement Learning Chatbot
#
#                                             abstract
# 0  We propose an architecture for VQA which utili...
# 1  Recent approaches based on artificial neural n...
# 2  We introduce the multiresolution recurrent neu...
# 3  Multi-task learning is motivated by the observ...
# 4  We present MILABOT: a deep reinforcement learn...

# %%
df_origin['abstract_clean'] = df_origin['abstract'].fillna('').str.replace('\n', ' ', regex=False)
df_origin['word_num'] = df_origin['abstract_clean'].str.count(' ') + 1
df_origin['sents_num'] = df_origin['abstract_clean'].str.count(r'[.!?]+ ') + 1

# %%
df_origin
# Out:
#       origin_idx            id  \
# 0              0  1802.00209v1
# 1              1  1603.03827v1
# 2              2  1606.00776v2
# 3              3  1705.08142v2
# 4              4  1709.02349v2
# ...          ...           ...
# 40995      40995   1404.4702v2
# 40996      40996   1404.5421v1
# 40997      40997   1404.5899v1
# 40998      40998   1404.6369v1
# 40999      40999   1407.0380v1
#
#                                                    title  \
# 0      Dual Recurrent Attention Units for Visual Ques...
# 1      Sequential Short-Text Classification with Recu...
# 2      Multiresolution Recurrent Neural Networks: An ...
# 3      Learning what to share between loosely related...
# 4                  A Deep Reinforcement Learning Chatbot
# ...                                                  ...
# 40995  Nearly Tight Bounds on $\ell_1$ Approximation ...
# 40996    Concurrent bandits and cognitive radio networks
# 40997  A Comparison of Clustering and Missing Data Me...
# ...

# %%
(df_origin.loc[0]['abstract'],
df_origin.loc[0]['abstract_clean'])
# Out:
# ('We propose an architecture for VQA which utilizes recurrent layers to\ngenerate visual and textual attention. The memory characteristic of the\nproposed recurrent attention units offers a rich joint embedding of visual and\ntextual features and enables the model to reason relations between several\nparts of the image and question. Our single model outperforms the first place\nwinner on the VQA 1.0 dataset, performs within margin to the current\nstate-of-the-art ensemble model. We also experiment with replacing attention\nmechanisms in other state-of-the-art models with our implementation and show\nincreased accuracy. In both cases, our recurrent attention mechanism improves\nperformance in tasks requiring sequential or relational reasoning on the VQA\ndataset.',
# ...

# %%
sns.histplot(df_origin['word_num'])
# Out:
# <Axes: xlabel='word_num', ylabel='Count'>

# %%
sns.histplot(df_origin['sents_num'])
# Out:
# <Axes: xlabel='sents_num', ylabel='Count'>

# %%
df_origin.min()
# Out:
# origin_idx                                                        0
# id                                                      0704.1020v1
# title             "Attention" for Detecting Unreliable News in t...
# abstract          "Background subtraction" is an old technique f...
# abstract_clean    "Background subtraction" is an old technique f...
# word_num                                                          3
# sents_num                                                         1
# dtype: object

# %%
df_origin.max()
# Out:
# origin_idx                                                    40999
# id                                               quant-ph/9907009v2
# title             μ-MAR: Multiplane 3D Marker based Registration...
# abstract          word2vec affords a simple yet powerful approac...
# abstract_clean    word2vec affords a simple yet powerful approac...
# word_num                                                        558
# sents_num                                                        32
# dtype: object

# %%
df_origin[df_origin['sents_num'] == 1]
# Out:
#       origin_idx            id  \
# 144          144  1503.00036v2
# 1411        1411  1701.05549v1
# 1674        1674  1712.05785v2
# 1887        1887  1803.07416v1
# 1969        1969  1703.03888v1
# ...          ...           ...
# 39514      39514  1607.07006v1
# 39761      39761  1703.09161v1
# 40360      40360  cs/0606100v4
# 40364      40364  cs/0611042v1
# 40459      40459   1110.2392v2
#
#                                                    title  \
# 144       Norm-Based Capacity Control in Neural Networks
# 1411              Deep Neural Networks - A Brief History
# 1674                 Sentiment Predictability for Stocks
# 1887        Tensor2Tensor for Neural Machine Translation
# 1969   Segmentation of skin lesions based on fuzzy cl...
# ...                                                  ...
# 39514  Autonomous Ingress of a UAV through a window u...
# 39761  A Dynamic Programming Solution to Bounded Deji...
# 40360  The generating function of the polytope of tra...
# ...

# %%
df_origin.loc[144]['abstract_clean']
# Out:
# 'We investigate the capacity, convexity and characterization of a general family of norm-constrained feed-forward networks.'

# %%
df_origin.loc[144]['word_num']
# Out:
# np.int64(15)

# %%
df_clean = df_origin[(df_origin['word_num'] >= 50) & (df_origin['sents_num'] <= 12) & (df_origin['word_num'] <= 250)]
df_clean
# Out:
#       origin_idx            id  \
# 0              0  1802.00209v1
# 1              1  1603.03827v1
# 2              2  1606.00776v2
# 3              3  1705.08142v2
# 4              4  1709.02349v2
# ...          ...           ...
# 40994      40994   1404.3656v1
# 40996      40996   1404.5421v1
# 40997      40997   1404.5899v1
# 40998      40998   1404.6369v1
# 40999      40999   1407.0380v1
#
#                                                    title  \
# 0      Dual Recurrent Attention Units for Visual Ques...
# 1      Sequential Short-Text Classification with Recu...
# 2      Multiresolution Recurrent Neural Networks: An ...
# 3      Learning what to share between loosely related...
# 4                  A Deep Reinforcement Learning Chatbot
# ...                                                  ...
# 40994                   Methods for Ordinal Peer Grading
# 40996    Concurrent bandits and cognitive radio networks
# 40997  A Comparison of Clustering and Missing Data Me...
# ...

# %%
sns.histplot(df_clean['word_num'])
# Out:
# <Axes: xlabel='word_num', ylabel='Count'>

# %%
sns.histplot(df_clean['sents_num'])
# Out:
# <Axes: xlabel='sents_num', ylabel='Count'>

# %%
df_clean.min()
# Out:
# origin_idx                                                        0
# id                                                      0704.1028v1
# title             "Attention" for Detecting Unreliable News in t...
# abstract          "Background subtraction" is an old technique f...
# abstract_clean    "Background subtraction" is an old technique f...
# word_num                                                         50
# sents_num                                                         1
# dtype: object

# %%
df_clean['title'] = df_origin['title'].fillna('').str.replace('\n', ' ', regex=False)
df_clean['title'] = df_origin['title'].fillna('').str.replace(r'\s+', ' ', regex=True)
df_clean['abstract_clean'] = df_origin['abstract_clean'].fillna('').str.replace(r'\s+', ' ', regex=False)

# %%
df_fin = df_clean[['origin_idx', 'id', 'title', 'abstract_clean']].copy()

# %%
df_fin.rename(columns={'id' : 'arxiv_id', 'abstract_clean' : 'abstract'}, inplace=True)

# %%
df_fin
# Out:
#       origin_idx      arxiv_id  \
# 0              0  1802.00209v1
# 1              1  1603.03827v1
# 2              2  1606.00776v2
# 3              3  1705.08142v2
# 4              4  1709.02349v2
# ...          ...           ...
# 40994      40994   1404.3656v1
# 40996      40996   1404.5421v1
# 40997      40997   1404.5899v1
# 40998      40998   1404.6369v1
# 40999      40999   1407.0380v1
#
#                                                    title  \
# 0      Dual Recurrent Attention Units for Visual Ques...
# 1      Sequential Short-Text Classification with Recu...
# 2      Multiresolution Recurrent Neural Networks: An ...
# 3      Learning what to share between loosely related...
# 4                  A Deep Reinforcement Learning Chatbot
# ...                                                  ...
# 40994                   Methods for Ordinal Peer Grading
# 40996    Concurrent bandits and cognitive radio networks
# 40997  A Comparison of Clustering and Missing Data Me...
# ...

# %%
df_fin.to_csv('../dataset/clean.tsv', sep='\t', index=False, encoding='utf-8-sig')

# %%
df_fin.loc[2]['abstract']
# Out:
# 'We introduce the multiresolution recurrent neural network, which extends the sequence-to-sequence framework to model natural language generation as two parallel discrete stochastic processes: a sequence of high-level coarse tokens, and a sequence of natural language tokens. There are many ways to estimate or learn the high-level coarse tokens, but we argue that a simple extraction procedure is sufficient to capture a wealth of high-level discourse semantics. Such procedure allows training the multiresolution recurrent neural network by maximizing the exact joint log-likelihood over both sequences. In contrast to the standard log- likelihood objective w.r.t. natural language tokens (word perplexity), optimizing the joint log-likelihood biases the model towards modeling high-level abstractions. We apply the proposed model to the task of dialogue response generation in two challenging domains: the Ubuntu technical support domain, and Twitter conversations. On Ubuntu, the model outperfo
# ...
